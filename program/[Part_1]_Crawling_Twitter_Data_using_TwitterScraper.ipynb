# %% [markdown]
# # **Crawling Using TwitterScraper Library**

# %% [markdown]
# Update : 22 May 2020

# %% [markdown]
# ### **[Part 1] Install Library**

# %% [markdown]
# Install TwitterScraper pada Local Machine

# %%
# !pip install twitterscraper
# Out:
# ...
#      |████████████████████████████████| 92kB 4.3MB/s
# ...
#   Created wheel for twitterscraper: filename=twitterscraper-1.4.0-cp36-none-any.whl size=11347 sha256=255ee10f29ab79860065018e1e96fa3e670914b1b02fe7c356dd2a70a7124785
#   Stored in directory: /root/.cache/pip/wheels/c2/9c/8b/7393e7bdc8abe6ce0d46c2ffae2035a1a2080a97ff0ddbdde6
# Successfully built twitterscraper
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### **[Part 2] Import Library**

# %%
import pandas as pd
import twitterscraper as ts
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}

# %% [markdown]
# ---

# %% [markdown]
# ### **[Part 3] Setup User Data**

# %%
array_of_users= ['pieterpitojo','rullyjoo277212','dee13431735','noveriani5','johnbralink',
                 'lamegogosa','yusrinacindil','boimakar','bgs_aulia', 'kembangmlathi', 'tristyanto76', 
                 'hayanaqu', 'cahyaadiputra7', 'roon3651', 'indahmel2', 'adoeldian', 'bagus_ardiansyh', 
                 'failcodes', 'azhry', 'hasbiziyadi', 'danarjon', 'andibayy', 'mhrsnty', 'erwepp', 'neng_jeprett', 
                 'zahrafaiza', 'angggiita', 'rmarlendi', 'fjarr_', 'iqbalmt06', 'ibnoemoesa', 'mathiinulhakim', 
                 'encenggondok15', 'ben_panji', 'aghuzk', 'rosydin17', 'sandi_alfarizie', 'rerew__', 'gianhervyagi', 
                 'imancibiuk99', 'adiosbxxch', 'jaluhpp', 'sahastiwi_endah', 'dancinseaweed', 'ardy1905', 'ricckyrpl', 
                 'farahsumayya', 'syahidun58', 'kenyulian', 'manakutau_mas', 'misbahulmunawa6', 'zoelfian18_', 'ceemplon', 
                 'talass_19', 'sh3_think', 'benuuir', 'lenyastriani', 'iboylagi', 'desartha', 'helminoris22', 'sitimaysarohxix', 
                 'rizqosyahril', 'djaya_karta', '_heyliaaa', 'boiisoasoapapu','smuhamad049', 'kamilmjd', 'hasbiarraihanm','ranasclok', 
                 'rizky_achmad_','yuskapityaji','ortsasybur', 'kammenrider', 'uniqnyaunii', 'ahmad_richad','antonwahyudi20','albabalpachino',
                 'fr_rudin', 'hendrajlek', 'madimaks17', 'ibnu_dumadi', 'rullypratama84','mbritodysey', 'darwiz_one', 'g_apunk', 
                 'miamariau', 'le_roslina', 'wayan_ekmt', 'akhmal_em', 'yoganugr', 'nyonriers', 'maukesana', 'adelle_ap', 'ilyas_arin','widadms17', 
                 'hasabibilal','cerita_lakon50' ,'razief991', 'rizkymaryadi','neaaara3', 'amrin_marvf','rahmatp_id', 'ikhwanusshofaM', 
                 'haremarem', 'bogiyuniar','riafiani', 'taufiqmarhab','helelsson', 'andhikopaw','serasamerdek', 'mutiaaksmi',
                 'ohsigalih', 'silviasanad','nurynprabw','beelloman', 'alanzhoo', 'komiichan96', 'akupundemiki', 
                 'faisalmahrus50', 'ranicyn',  'nonyuliii',  'boyhendryko', 'ifanugrh', 'yuliantonuh', 'djoko_saja', 'putra_matra', 
                 'azmii_aziz', 'rendy_ris', 'nursii5', 'edoriydho', 'anindramoelya', 'robbyanto90', 'rahmadiheru88', 
                 'rezimtipudaya', 'gunturmataram', 'srisumaryani', 'beny_fian', 'aryoramangan', 'dinarsbakti', 'ivansiregar18', 'apaajadehyaok', 'marsha_chichi',
                 'adamnain', 'farisalfarabi11', 'maslan_zr', 'nrrmlhs', 'rsmnptr_', 'endry_he', 'hansip07',
                 'yogarendras', 'rubkaryo323', 'fanimaya', 'adilmer4', 'ikawahyu_n', 'bolehdikosongin', 'welgeduwel_beh', 'kikihakim', 
                 'paol_paul', 'namanyasisca', 'ariefsulaiman02', 'qaddim_95', 'nurwahyudin460', 'iqramuh_', 'xmerissax', 
                 'ahmad310017', 'dnswr__', 'godx1va', 'devinnugroho1', 'sfambrr', 'hdafi', 'reykurihiku', 'apasihrii', 
                 'usaisudahhh', 'sarwohadi_p', 'ekakaay', 'ezash', 'yumglg', 'danangsett', 'ayy_only', 'intplp']

# %%
print(len(array_of_users))
# Out:
# 180

# %% [markdown]
# ---

# %% [markdown]
# ### **[Part 4] Crawling Process**

# %%
import time
start_time = time.time()

limit = 150

list_tweets = []
tweets      = [None] * len(array_of_users)

for i in range(0, len(array_of_users)):
  tweets[i]   = ts.query.query_tweets_from_user(array_of_users[i], limit=limit)
  list_tweets.append(tweets[i])

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# INFO: Using proxy 181.143.106.162:39617
# INFO: Scraping tweets from https://twitter.com/i/profiles/show/azhry/timeline/tweets?include_available_features=1&include_entities=1&max_position=1241992973123903488&reset_error_state=false
# INFO: Using proxy 150.129.250.28:33846
# INFO: Scraping tweets from https://twitter.com/i/profiles/show/azhry/timeline/tweets?include_available_features=1&include_entities=1&max_position=1239532870852587520&reset_error_state=false
# INFO: Using proxy 193.110.115.220:3128
# INFO: Scraping tweets from https://twitter.com/i/profiles/show/azhry/timeline/tweets?include_available_features=1&include_entities=1&max_position=1235406822477099008&reset_error_state=false
# INFO: Using proxy 64.227.126.31:3128
# INFO: Scraping tweets from https://twitter.com/i/profiles/show/azhry/timeline/tweets?include_available_features=1&include_entities=1&max_position=1229360479409074177&reset_error_state=false
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### **[Part 5] Convert Crawling Data into Single List**

# %%
import itertools
merged = list(itertools.chain(*list_tweets))

# %%
df = pd.DataFrame(t.__dict__ for t in merged)

# %%
df.tail()
# Out:
#           screen_name username  ... parent_tweet_id reply_to_users
# 23613          intplp    intan  ...                             []
# 23614  CallHerAbigail        -  ...                             []
# 23615          intplp    intan  ...                             []
# 23616          intplp    intan  ...                             []
# 23617          intplp    intan  ...                             []
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (23618, 21)

# %% [markdown]
# ---

# %% [markdown]
# ### **[Part 7] Export Extensive Dataset**

# %%
from google.colab import files

df.to_csv('extensive_dataset.csv', index=False, sep='~') 
files.download('extensive_dataset.csv')

# %% [markdown]
# ---

# %% [markdown]
# ### **[Part 8] Original Tweet without Retweet Data**

# %%
is_replied   = df['is_replied']  == False
is_reply_to  = df['is_reply_to'] == False

df = df[(is_replied) & (is_reply_to)]

# %%
df = (df.iloc[:, [0, 1, 7]])

# %%
df.shape
# Out:
# (8810, 3)

# %% [markdown]
# ---

# %% [markdown]
# ### **[Part 9] Export Narrow Dataset**

# %%
from google.colab import files

df.to_csv('narrow_dataset.csv', index=False, sep='~') 
files.download('narrow_dataset.csv')

# %% [markdown]
# ---
